# %% [markdown]
# ### Analyse des résultats de l'immersion

# %%
from Analyse import *
from save_video import *

# %% [markdown]
# ## Avec ema

# %%
print_reward_mean('drl', ymin=-1, ymax=1.5, y=None, title="Reward avec ema", legend_pointille= None)
print_area_mean('drl', ymin=-14, ymax=-13, y=None, title=None, legend_pointille= None)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 print_reward_mean('drl', ymin=-1, ymax=1.5, y=None, title="Reward avec ema", legend_pointille= None)
#       2 print_area_mean('drl', ymin=-14, ymax=-13, y=None, title=None, legend_pointille= None)
#
# File ~/Desktop/mines_2A/TR_fluide/docs_drl/Analyse.py:141, in print_reward_mean(file, ymin, ymax, y, title, legend_pointille)
#     140 def print_reward_mean(file, ymin=-1, ymax=3.5, y=None, title=None, legend_pointille= None):
# --> 141     df_values = pd.read_csv(file + "/Values.txt", sep="\t", header=0)
#     142     result_max = df_values.groupby(df_values['Index']).max()
#     143     plt.plot(result_max.index, result_max['Reward'], color = 'b', label='Max')
#
# ...
