# %%
from convert_naca import *

# %%
naca_profile = ["0009", "0024", "1408", "2410", "2412", "2414", "2415", "2421", "4412", "6412"]
naca_profile_coord = dict()

# %%
naca_63415 = convert_naca_profile_curb("naca/naca_63415.txt", title=f"Naca 63415")
# Out:
# Optimization terminated successfully.
#          Current function value: 0.236027
#          Iterations: 12
#          Function evaluations: 5005

# %%
naca_63415
# Out:
# array([ 0.02312831,  0.04979696,  0.09752639,  0.09891683,  0.06405409,
#        -0.04646897, -0.05629325, -0.01144421,  0.72674268, -0.00904017])

# %%
naca_63215 = convert_naca_profile_curb("naca/naca_63215.txt", title=f"Naca 63215")
# Out:
# Optimization terminated successfully.
#          Current function value: 0.212842
#          Iterations: 16
#          Function evaluations: 6841

# %%
naca_63215
# Out:
# array([ 0.02267468,  0.03502696,  0.08531651,  0.08768866,  0.05825892,
#        -0.05514708, -0.06891857, -0.0253396 ,  0.74175824, -0.00467257])

# %%
for profile in naca_profile : 
    naca_profile_coord[profile] = convert_naca_profile("naca/naca_"+profile+".txt", title=f"Naca #{profile}")
# Out:
# Optimization terminated successfully.
#          Current function value: 0.075578
#          Iterations: 11
#          Function evaluations: 3992
# Optimization terminated successfully.
#          Current function value: 0.350160
#          Iterations: 9
#          Function evaluations: 3233
# Optimization terminated successfully.
#          Current function value: 0.114319
#          Iterations: 13
#          Function evaluations: 4353
# Optimization terminated successfully.
#          Current function value: 0.145178
#          Iterations: 14
#          Function evaluations: 4566
# Optimization terminated successfully.
#          Current function value: 0.064881
#          Iterations: 7
#          Function evaluations: 2600
# Optimization terminated successfully.
#          Current function value: 0.108100
#          Iterations: 10
#          Function evaluations: 3729
# Optimization terminated successfully.
#          Current function value: 0.217345
#          Iterations: 10
#          Function evaluations: 3711
# Optimization terminated successfully.
#          Current function value: 0.302315
#          Iterations: 12
#          Function evaluations: 4122
# Optimization terminated successfully.
#          Current function value: 0.182358
#          Iterations: 12
#          Function evaluations: 4101
# Optimization terminated successfully.
#          Current function value: 0.138831
#          Iterations: 9
#          Function evaluations: 3208

# %% [markdown]
#  ## Test avec code avec courbure

# %%
naca_profile_coord_curb = dict()
for profile in naca_profile : 
    naca_profile_coord_curb[profile] = convert_naca_profile_curb("naca/naca_"+profile+".txt", title=f"Naca {profile}")
# Out:
# Optimization terminated successfully.
#          Current function value: 0.075515
#          Iterations: 19
#          Function evaluations: 8044
# Optimization terminated successfully.
#          Current function value: 0.351273
#          Iterations: 12
#          Function evaluations: 5401
# Optimization terminated successfully.
#          Current function value: 0.114368
#          Iterations: 18
#          Function evaluations: 8279
# Optimization terminated successfully.
#          Current function value: 0.145097
#          Iterations: 8
#          Function evaluations: 3417
# Optimization terminated successfully.
#          Current function value: 0.064882
#          Iterations: 7
#          Function evaluations: 2999
# Optimization terminated successfully.
#          Current function value: 0.107676
#          Iterations: 12
#          Function evaluations: 5337
# Optimization terminated successfully.
#          Current function value: 0.216956
#          Iterations: 10
#          Function evaluations: 4347
# Optimization terminated successfully.
#          Current function value: 0.302285
#          Iterations: 9
#          Function evaluations: 4029
# Optimization terminated successfully.
#          Current function value: 0.181280
#          Iterations: 15
#          Function evaluations: 6509
# Optimization terminated successfully.
#          Current function value: 0.138922
#          Iterations: 10
#          Function evaluations: 4095

# %%
naca_profile_coord_curb
# Out:
# {'0009': array([ 0.02105022,  0.02386667,  0.03977471,  0.04647642,  0.03617244,
#         -0.04407917, -0.04688428, -0.03158979,  0.34369521,  0.00147708]),
#  '0024': array([ 0.05204743,  0.06303105,  0.10814945,  0.12784607,  0.0987161 ,
#         -0.11122873, -0.12082101, -0.07898672,  0.00020073, -0.00526584]),
#  '1408': array([ 0.01577301,  0.02634991,  0.04458271,  0.04984893,  0.03596771,
#         -0.03299942, -0.03122371, -0.01889866,  0.00118624,  0.00233561]),
#  '2410': array([ 0.02053173,  0.04009762,  0.06680853,  0.07187184,  0.04994712,
#         -0.03357309, -0.02884734, -0.01461827,  0.64838407, -0.00323748]),
#  '2412': array([ 0.02359928,  0.04828674,  0.07590444,  0.08340451,  0.05728329,
#         -0.04362299, -0.03815534, -0.02214095,  0.7004262 , -0.00406199]),
#  '2414': array([ 0.02906834,  0.05352195,  0.08538086,  0.09405467,  0.06812678,
#         -0.05169674, -0.0488069 , -0.02716718,  0.68306362, -0.00521114]),
#  '2415': array([ 0.0295119 ,  0.05687803,  0.08926204,  0.09879451,  0.07186289,
#         -0.05725947, -0.05247905, -0.02971745,  0.81955846, -0.00664571]),
#  '2421': array([ 0.04375757,  0.07137331,  0.11645757,  0.12994691,  0.0973322 ,
#         -0.08436283, -0.08455847, -0.04858665,  0.76263157, -0.00688066]),
#  '4412': array([ 2.43489131e-02,  6.30465104e-02,  9.71943430e-02,  1.03387234e-01,
#          6.91344494e-02, -2.91755161e-02, -1.62810212e-02, -5.99757920e-04,
#          8.95586376e-01, -9.29451562e-03]),
#  '6412': array([ 0.02340366,  0.08213517,  0.12281425,  0.12498064,  0.08461117,
#         -0.01325784,  0.00811609,  0.02124909,  0.67690661, -0.0171881 ])}
